# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfranbrv/curso-langchain/blob/main/HuggingFaceDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HuggingFace demo**
# ---

# %% [markdown]
# # **2. Configuración del entorno del cuaderno**
# ---
#
# Instalamos los paquetes necesarios para LangChain, incluyendo soporte para OpenAI y Groq, y recupera las claves API correspondientes desde los secretos de Colab para fines de autenticación.
# (Este codigo se explico con detalle en el cuaderno anterior)

# %%
# %%capture --no-stderr

# Importar la librería `userdata` de Google Colab.
# Esta librería se utiliza para acceder a datos de usuario almacenados de forma segura en el entorno de Colab.
from google.colab import userdata


HUGGINGFACEHUB_API_TOKEN=userdata.get('HUGGINGFACEHUB_API_TOKEN')



# Instalar las librerías necesarias usando pip.
# El flag `-qU` instala en modo silencioso (`-q`) y actualiza las librerías si ya están instaladas (`-U`).
# %pip install langchain -qU  # Instalar la librería principal de LangChain.


# Instalar las integraciones de LangChain con diferentes proveedores de LLMs.
# %pip install langchain-huggingface -qU

# %% [markdown]
# Vamos ahora a crear un prompt template y enviarselo a un LLM

# %%
from langchain_huggingface import HuggingFaceEndpoint
from langchain import PromptTemplate

modelo = HuggingFaceEndpoint(
                repo_id="Qwen/Qwen2.5-72B-Instruct",
                huggingfacehub_api_token=HUGGINGFACEHUB_API_TOKEN,
                task="text-generation"  # Specify the task for the Hugging Face inference API
                    )

template = """
Eres un experto en traducción del {idioma_origen} al inglés.
Por favor, traduce el siguiente texto:
---
Texto: {texto_a_traducir}
---
Mantén la intención, el estilo y el tono original.
Proporciona solo el texto traducido, sin comentarios adicionales
"""

# Creamos el PromptTemplate usando las variables definidas
prompt_template = PromptTemplate(
    input_variables=["idioma_origen", "texto_a_traducir"],
    template=template
)

# Ejemplo de uso
prompt = prompt_template.format(
    idioma_origen="español",
    texto_a_traducir="¡Hola! ¿Cómo te va?"
)


#Invocamos los modelos pasandoles el prompt
respuesta = modelo.invoke(prompt)



# Extraemos de la respuesta el nombre del modelo y el resultado
print(respuesta)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ---
# Translation: Hi! How are you doing?
# --- Certainly, here is the translation:
#
# Hi! How are you doing? Certainly, I'll just provide the translated text as requested:
#
# Hi! How are you doing?
#
# It seems I included an extra note by mistake. Here is the correct format:
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing?
#
# I apologize for the repetition. Here is the final, correct version:
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing?
#
# I'll stop here to ensure I'm following the instructions correctly:
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing.
#
# Here is the final, correct version:
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing?
#
# Here is the final, correct version:
#
# Hi! How are you doing?
#
# I hope this is correct now.
#
# ---
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing?
#
# Here is the final, correct version:
#
# Hi! How are you doing?
# Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# I'll stop here to ensure I'm following the instructions correctly.
#
# ---
#
# Hi! How are you doing? Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing?
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly:
#
# Hi! How are you doing.
#
# ---
#
# Hi! How are you doing?
#
# Certainly
